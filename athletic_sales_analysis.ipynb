# %%
# Import Libraries and Dependencies
import pandas as pd

# %% [markdown]
# ### 1. Combine and Clean the Data
# #### Import CSVs

# %%
# Read the CSV files into DataFrames.
athletic_sales_2020_df = pd.read_csv('Resources/athletic_sales_2020.csv')
athletic_sales_2021_df = pd.read_csv('Resources/athletic_sales_2021.csv')

# %%
# Display the 2020 sales DataFrame
athletic_sales_2020_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0     Foot Locker      1185732       1/1/20  Northeast      New York
# 1     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3     Foot Locker      1185732       1/1/20  Northeast      New York
# 4     Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 1292    West Gear      1128299     12/30/20       West    California
# 1293    West Gear      1128299     12/30/20       West    California
# 1294       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1295       Kohl's      1189833     12/30/20    Midwest     Minnesota
# 1296    West Gear      1128299     12/30/20       West    California
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %%
# Display the 2021 sales DataFrame
athletic_sales_2021_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 0       West Gear      1128299       1/1/21       West    California
# 1       West Gear      1128299       1/1/21       West    California
# 2          Kohl's      1189833       1/1/21    Midwest       Montana
# 3          Kohl's      1189833       1/1/21    Midwest       Montana
# 4       West Gear      1128299       1/1/21       West    California
# ...           ...          ...          ...        ...           ...
# 8341  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8342  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
# 8343       Amazon      1185732     12/31/21  Northeast         Maine
# 8344       Amazon      1185732     12/31/21  Northeast         Maine
# 8345  Foot Locker      1185732     12/31/21  Northeast  Pennsylvania
#
#                city                  product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Check the data types of each DataFrame

# %%
# Check the 2020 sales data types.
athletic_sales_2020_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Check the 2021 sales data types.
athletic_sales_2021_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %% [markdown]
# #### Combine the sales data by rows.

# %%
# Combine the 2020 and 2021 sales DataFrames on the rows and reset the index.
combined_df = pd.concat([athletic_sales_2020_df, athletic_sales_2021_df], axis=0, join='inner').reset_index(drop=True)
combined_df.head()
# Out:
#       retailer  retailer_id invoice_date     region         state  \
# 0  Foot Locker      1185732       1/1/20  Northeast      New York
# 1  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 2  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
# 3  Foot Locker      1185732       1/1/20  Northeast      New York
# 4  Foot Locker      1185732       1/1/20  Northeast  Pennsylvania
#
#            city                product  price_per_unit  units_sold  \
# 0      New York  Men's Street Footwear              50        1200
# 1  Philadelphia        Women's Apparel              68          83
# 2  Philadelphia        Women's Apparel              75         275
# 3      New York  Men's Street Footwear              34         384
# 4  Philadelphia        Women's Apparel              53          83
#
#    total_sales  operating_profit sales_method
# 0       600000         300000.00     In-store
# 1         5644           2426.92       Online
# ...

# %%
# Check if any values are null.
combined_df.isnull().sum()
# Out:
# retailer            0
# retailer_id         0
# invoice_date        0
# region              0
# state               0
# city                0
# product             0
# price_per_unit      0
# units_sold          0
# total_sales         0
# operating_profit    0
# sales_method        0
# dtype: int64

# %%
# Check the data type of each column
combined_df.dtypes
# Out:
# retailer             object
# retailer_id           int64
# invoice_date         object
# region               object
# state                object
# city                 object
# product              object
# price_per_unit        int64
# units_sold            int64
# total_sales           int64
# operating_profit    float64
# sales_method         object
# dtype: object

# %%
# Convert the "invoice_date" to a datetime datatype
combined_df.reset_index(inplace=True)
combined_df['invoice_date']= pd.to_datetime(combined_df['invoice_date'], errors='coerce')
combined_df.set_index('invoice_date', inplace=True)

# %%
# Confirm that the "invoice_date" data type has been changed.
combined_df
# Out:
#               level_0  index     retailer  retailer_id     region  \
# invoice_date
# 2020-01-01          0      0  Foot Locker      1185732  Northeast
# 2020-01-01          1      1  Foot Locker      1185732  Northeast
# 2020-01-01          2      2  Foot Locker      1185732  Northeast
# 2020-01-01          3      3  Foot Locker      1185732  Northeast
# 2020-01-01          4      4  Foot Locker      1185732  Northeast
# ...               ...    ...          ...          ...        ...
# 2021-12-31       9638   9638  Foot Locker      1185732  Northeast
# 2021-12-31       9639   9639  Foot Locker      1185732  Northeast
# 2021-12-31       9640   9640       Amazon      1185732  Northeast
# 2021-12-31       9641   9641       Amazon      1185732  Northeast
# 2021-12-31       9642   9642  Foot Locker      1185732  Northeast
#
#                      state          city                product  \
# invoice_date
# 2020-01-01        New York      New York  Men's Street Footwear
# ...

# %% [markdown]
# ### 2. Determine which Region Sold the Most Products

# %% [markdown]
# #### Using `groupby`

# %%
# Show the number products sold for region, state, and city.
products_df = combined_df.groupby(['region', 'state', 'city'])['units_sold'].agg(Total_Products_Sold=("sum")).reset_index()

# Rename the sum to "Total_Products_Sold".

# Show the top 5 results.
top_5 = products_df.sort_values(by=(["Total_Products_Sold"]),ascending=False).head()
top_5
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the number products sold for region, state, and city.
pivot_df = combined_df.pivot_table(
    values='units_sold',
    index=['region', 'state', 'city'],
    aggfunc='sum'
).reset_index()

# Rename the "units_sold" column to "Total_Products_Sold"
pivot_df.rename(columns={'units_sold': 'Total_Products_Sold'}, inplace=True)

# Show the top 5 results.
top_5 = pivot_df.sort_values(by=(["Total_Products_Sold"]),ascending=False).head()
top_5
# Out:
#        region       state           city  Total_Products_Sold
# 21  Northeast    New York       New York               111954
# 33      South       Texas        Houston                90322
# 44       West  California  San Francisco                85478
# 43       West  California    Los Angeles                76384
# 34  Southeast     Florida          Miami                73135

# %% [markdown]
# ### 3. Determine which Region had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each region, state, and city.
total_sales_df = combined_df.groupby(['region', 'state', 'city'])['total_sales'].agg(Total_Sales=("sum")).reset_index()
# Rename the "total_sales" column to "Total Sales"
total_sales_df.rename(columns={'total_sales': 'Total_Sales'}, inplace=True)

# Show the top 5 results.
top_5 = total_sales_df.sort_values(by=(["Total_Sales"]),ascending=False).head()
top_5
# Out:
#        region           state           city  Total_Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each region, state, and city.
pivot_df = combined_df.pivot_table(
    values='total_sales',
    index=['region', 'state', 'city'],
    aggfunc='sum'
).reset_index()


# Optional: Rename the "total_sales" column to "Total Sales"
pivot_df.rename(columns={'total_sales': 'Total_Sales'}, inplace=True)

# Show the top 5 results.
top_5 = total_sales_df.sort_values(by=(["Total_Sales"]),ascending=False).head()
top_5
# Out:
#        region           state           city  Total_Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# ### 4. Determine which Retailer had the Most Sales

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
sales_df = combined_df.groupby(['retailer', 'region', 'state', 'city'])['total_sales'].agg(Total_Sales=("sum")).reset_index()

# Rename the "total_sales" column to "Total Sales"
sales_df.rename(columns={'total_sales': 'Total_Sales'}, inplace=True)

# Show the top 5 results.
top_5 = sales_df.sort_values(by=(["Total_Sales"]),ascending=False).head()
top_5
# Out:
#         retailer     region           state           city  Total_Sales
# 103    West Gear       West      California  San Francisco     32794405
# 50        Kohl's       West      California    Los Angeles     25127160
# 22   Foot Locker  Northeast        New York       New York     25008568
# 109    West Gear       West      Washington        Seattle     24862675
# 33   Foot Locker  Southeast  South Carolina     Charleston     24822280

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total sales for the products sold for each retailer, region, state, and city.
pivot_df = combined_df.pivot_table(
    values='total_sales',
    index=['retailer', 'region', 'state', 'city'],
    aggfunc='sum'
).reset_index()

# Optional: Rename the "total_sales" column to "Total Sales"
pivot_df.rename(columns={'total_sales': 'Total_Sales'}, inplace=True)

# Show the top 5 results.
top_5 = total_sales_df.sort_values(by=(["Total_Sales"]),ascending=False).head()
top_5
# Out:
#        region           state           city  Total_Sales
# 21  Northeast        New York       New York     39801235
# 44       West      California  San Francisco     33973228
# 34  Southeast         Florida          Miami     31600863
# 39  Southeast  South Carolina     Charleston     29285637
# 35  Southeast         Florida        Orlando     27682851

# %% [markdown]
# ### 5. Determine which Retailer Sold the Most Women's Athletic Footwear

# %%
# Filter the sales data to get the women's athletic footwear sales data.
womens_footwear_sales_df = combined_df[combined_df["product"].str.contains("Women's Athletic Footwear")]
womens_footwear_sales_df
# Out:
#          retailer  retailer_id invoice_date     region         state  \
# 21    Foot Locker      1185732       1/4/20  Northeast      New York
# 22    Foot Locker      1185732       1/4/20  Northeast      New York
# 23    Foot Locker      1185732       1/4/20  Northeast      New York
# 26      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# 27      West Gear      1128299       1/5/20  Northeast  Pennsylvania
# ...           ...          ...          ...        ...           ...
# 9633  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9634  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
# 9635       Amazon      1185732     12/30/21  Northeast         Maine
# 9636       Amazon      1185732     12/30/21  Northeast         Maine
# 9637  Foot Locker      1185732     12/30/21  Northeast  Pennsylvania
#
#               city                    product  price_per_unit  units_sold  \
# ...

# %% [markdown]
# #### Using `groupby`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
womens_footwear_sold_df = womens_footwear_sales_df.groupby(['retailer', 'region', 'state', 'city'])['units_sold'].agg(units_sold=("sum")).reset_index()

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
womens_footwear_sold_df.rename(columns={'units_sold': 'Womens_Footwear_Units_Sold'}, inplace=True)

# Show the top 5 results.
top_5 = womens_footwear_sold_df.sort_values(by=(["Womens_Footwear_Units_Sold"]),ascending=False).head()
top_5
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %% [markdown]
# #### Using `pivot_table`

# %%
# Show the total number of women's athletic footwear sold for each retailer, region, state, and city.
pivot_df = combined_df.pivot_table(
    values='units_sold',
    index=['retailer', 'region', 'state', 'city'],
    aggfunc='sum'
).reset_index()

# Rename the "units_sold" column to "Womens_Footwear_Units_Sold"
pivot_df.rename(columns={'units_sold': 'Womens Footwear Units Sold'}, inplace=True)

# Show the top 5 results.
top_5 = womens_footwear_sold_df.sort_values(by=(["Womens_Footwear_Units_Sold"]),ascending=False).head()
top_5
# Out:
#           retailer     region           state           city  \
# 101      West Gear       West      California  San Francisco
# 22     Foot Locker  Northeast        New York       New York
# 49          Kohl's       West      California    Los Angeles
# 33     Foot Locker  Southeast  South Carolina     Charleston
# 68   Sports Direct      South           Texas         Dallas
#
#      Womens_Footwear_Units_Sold
# 101                       12107
# 22                        10996
# 49                        10826
# 33                         8814
# 68                         8790

# %% [markdown]
# ### 6. Determine the Day with the Most Women's Athletic Footwear Sales

# %%
# Create a pivot table with the 'invoice_date' column is the index, and the "total_sales" as the values.
sales_pivot_sum = pd.pivot_table(combined_df,
    values='total_sales',
    index=['invoice_date'],
    aggfunc='sum'
).reset_index()

# Optional: Rename the "total_sales" column to "Total Sales"
sales_pivot_sum.rename(columns={'total_sales': 'Total_Sales'}, inplace=True)

# Show the table.
sales_pivot_sum
# Out:
#     invoice_date  Total_Sales
# 0     2020-01-01       845141
# 1     2020-01-02       689410
# 2     2020-01-03       632573
# 3     2020-01-04       615080
# 4     2020-01-05       707829
# ..           ...          ...
# 718   2021-12-27       602353
# 719   2021-12-28       301010
# 720   2021-12-29       211109
# 721   2021-12-30       167903
# 722   2021-12-31       198659
#
# [723 rows x 2 columns]

# %%
# Resample the pivot table into daily bins, and get the total sales for each day.
daily_sales = sales_pivot_sum.resample('D').sum()

# Sort the resampled pivot table in descending order on "Total Sales".
daily_sales.sort_values(by="Total_Sales", ascending=False)

daily_sales
# Out:
#               Total_Sales
# invoice_date
# 2020-01-01         845141
# 2020-01-02         689410
# 2020-01-03         632573
# 2020-01-04         615080
# 2020-01-05         707829
# ...                   ...
# 2021-12-27         602353
# 2021-12-28         301010
# 2021-12-29         211109
# 2021-12-30         167903
# 2021-12-31         198659
#
# [731 rows x 1 columns]

# %% [markdown]
# ### 7.  Determine the Week with the Most Women's Athletic Footwear Sales

# %%
# Resample the pivot table into weekly bins, and get the total sales for each week.
weekly_sales = sales_pivot_sum.resample('W').sum()

# Sort the resampled pivot table in descending order on "Total Sales".
weekly_sales.sort_values(by="Total_Sales", ascending=False)

weekly_sales
# Out:
#               Total_Sales
# invoice_date
# 2020-01-05        3490033
# 2020-01-12        2837846
# 2020-01-19        1410638
# 2020-01-26        4831822
# 2020-02-02        5353189
# ...                   ...
# 2021-12-05       14148357
# 2021-12-12       23250286
# 2021-12-19       24698535
# 2021-12-26       14467751
# 2022-01-02        1481034
#
# [105 rows x 1 columns]
